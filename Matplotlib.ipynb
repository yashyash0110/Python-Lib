# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### The plot() function is used to draw points in a diagram.
# By default, the plot() function draws a line from point to point.
# The function takes parameters for specifying points in the diagram.

# %%
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
#Plotting without line
plt.plot(xpoints,ypoints,'o')
plt.show()

# %% [markdown]
# ### Multiple Points

# %%
#Multiple Points
#Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):
xpoints=np.array([1,2,3,4])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %% [markdown]
# ### Default X-Points

# %% [markdown]
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 (etc., depending on the length of the y-points.

# %%
ypoints=np.array([3,4,10,5,8])
plt.plot(ypoints)
plt.show()

# %% [markdown]
# ## Markers

# %% [markdown]
# You can use the keyword argument marker to emphasize each point with a specified marker:

# %%
ypoints=np.array([3,8,1,1])
plt.plot(ypoints,marker='o')
plt.show()

# %%
plt.plot(ypoints,marker='*')
plt.show()

# %% [markdown]
# ### Format Strings fmt

# %% [markdown]
# You can use also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %%
plt.plot(ypoints,'*:b')
plt.show()

# %% [markdown]
# ## Marker Size and Marker Color

# %% [markdown]
# You can use the keyword argument markersize or the shorter version, ms to set the size of the markers.
#
# You can use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers
#
# You can use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers
#
# Use both the mec and mfc arguments to color the entire marker

# %%
plt.plot(ypoints,marker="o",ms=20)
plt.show()

# %%
plt.plot(ypoints,"o-.m",ms=15)
plt.show()

# %%
plt.plot(ypoints,"o-.m",ms=15,mec='r')
plt.show()

# %%
plt.plot(ypoints,"o-.m",ms=15,mfc='g')
plt.show()

# %%
plt.plot(ypoints,"o-.m",ms=15,mec="g",mfc='g')
plt.show()

# %% [markdown]
# ## Linestyle

# %% [markdown]
# You can use the keyword argument linestyle, or shorter ls, to change the style of the plotted line

# %%
plt.plot(ypoints,ls='dotted',marker="*")
plt.show()

# %% [markdown]
# ## Line Color

# %% [markdown]
# You can use the keyword argument color or the shorter c to set the color of the line

# %%
plt.plot(ypoints,c='g',marker='o',mec='m',mfc='m')
plt.show()

# %% [markdown]
# ## Line Width

# %% [markdown]
# You can use the keyword argument linewidth or the shorter lw to change the width of the line

# %%
plt.plot(ypoints,lw='20.5')
plt.show()

# %% [markdown]
# ## Multiple Lines

# %% [markdown]
# You can plot as many lines as you like by simply adding more plt.plot() functions

# %%
y1=np.array([3,8,1,10])
y2=np.array([6,2,7,11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %% [markdown]
# ### Create Labels for a Plot

# %% [markdown]
# With Pyplot, you can use the xlabel() and ylabel() functions to set a label for the x- and y-axis

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110,115,120,125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# ## Create a Title for a Plot

# %% [markdown]
# With Pyplot, you can use the title() function to set a title for the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,5,9])
y=np.array([3,6,9,12,34])
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
# Out:
# Text(0, 0.5, 'Calorie Burnage')

# %% [markdown]
# ## Set Font Properties for Title and Labels

# %% [markdown]
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,5,9])
y=np.array([3,6,9,12,34])
font1={'family':'monospace','color':'blue','size':15}
font2={'family':'serif','color':'red','size':20}
plt.plot(x,y,c='b',marker='o',mfc='g',mec='m',ls=":",ms=12)
plt.title("Sports Watch Data",fontdict=font1)
plt.xlabel("Average Pulse",fontdict=font2)
plt.ylabel("Calorie Burnage",fontdict=font2)
# Out:
# Text(0, 0.5, 'Calorie Burnage')

# %% [markdown]
# ## Position the Title

# %% [markdown]
# You can use the loc parameter in title() to position the title.
#
# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,5,9])
y=np.array([3,6,9,12,34])
plt.plot(x,y)
plt.title("Sports Watch Data",loc='left',fontdict=font1)
plt.xlabel("Average Pulse",fontdict=font2)
plt.ylabel("Calorie Burnage",fontdict=font2)
# Out:
# Text(0, 0.5, 'Calorie Burnage')

# %% [markdown]
# ## Add Grid Lines to a Plot

# %% [markdown]
# With Pyplot, you can use the grid() function to add grid lines to the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,5,9])
y=np.array([3,6,9,12,34])
plt.plot(x,y,marker='*')
plt.title("Sports Watch Data",loc='left',fontdict=font1)
plt.xlabel("Average Pulse",fontdict=font2)
plt.ylabel("Calorie Burnage",fontdict=font2)
plt.grid()
plt.show()

# %% [markdown]
# ## Specify Which Grid Lines to Display

# %% [markdown]
# You can use the axis parameter in the grid() function to specify which grid lines to display.
#
# Legal values are: 'x', 'y', and 'both'. Default value is 'both'.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,5,9])
y=np.array([3,6,9,12,34])
plt.plot(x,y,marker='*')
plt.title("Sports Watch Data",loc='left',fontdict=font1)
plt.xlabel("Average Pulse",fontdict=font2)
plt.ylabel("Calorie Burnage",fontdict=font2)
plt.grid(axis='x')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,5,9])
y=np.array([3,6,9,12,34])
plt.plot(x,y,marker='*')
plt.title("Sports Watch Data",loc='left',fontdict=font1)
plt.xlabel("Average Pulse",fontdict=font2)
plt.ylabel("Calorie Burnage",fontdict=font2)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Set Line Properties for the Grid

# %% [markdown]
# You can also set the line properties of the grid, like this: grid(color = 'color', linestyle = 'linestyle', linewidth = number).

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,5,9])
y=np.array([3,6,9,12,34])
plt.plot(x,y,marker='*')
plt.title("Sports Watch Data",loc='left',fontdict=font1)
plt.xlabel("Average Pulse",fontdict=font2)
plt.ylabel("Calorie Burnage",fontdict=font2)
plt.grid(c='g',ls="--",lw=1)
plt.show()

# %% [markdown]
# # Display Multiple Plots

# %% [markdown]
# ### **The subplot() Function**

# %% [markdown]
# * The subplot() function takes three arguments that describes the layout of the figure.
#
# * The layout is organized in rows and columns, which are represented by the first and second argument.
#
# * The third argument represents the index of the current plot.

# %% [markdown]
# With the subplot() function you can draw multiple plots in one figure.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,5,9])
y=np.array([3,6,9,12,34])
plt.subplot(1,2,1)#the figure has 1 row and 2 columns and this plot is the first plot.
plt.plot(x,y)
a=np.array([1,9,10,3])
b=np.array([5,8,0,2])
plt.subplot(1,2,2)#the figure has 1 row and 2 columns and this plot is the second plot.
plt.plot(a,b)
plt.show()

# %% [markdown]
# So, if we want a figure with 2 rows an 1 column (meaning that the two plots will be displayed on top of each other instead of side-by-side), we can write the syntax like this:

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,5,9])
y=np.array([3,6,9,12,34])
plt.subplot(2,1,1)#the figure has 2 rows and 1 column and this plot is the first plot.
plt.plot(x,y)
a=np.array([1,9,10,3])
b=np.array([5,8,0,2])
plt.subplot(2,1,2)#the figure has 2 rows and 1 column and this plot is the second plot.
plt.plot(a,b)
plt.show()

# %% [markdown]
# You can draw as many plots you like on one figure, just descibe the number of rows, columns, and the index of the plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ## Title

# %% [markdown]
# You can add a title to each plot with the title() function

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,9,5])
y=np.array([5,8,9,12])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Sales")

a=np.array([1,0,7,6])
b=np.array([7,4,9,12])
plt.subplot(1,2,2)
plt.plot(a,b)
plt.title("Income")

plt.show()

# %% [markdown]
# ## Super Title
#
# You can add a title to the entire figure with the suptitle() function:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,9,5])
y=np.array([5,8,9,12])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Sales")

a=np.array([1,0,7,6])
b=np.array([7,4,9,12])
plt.subplot(1,2,2)
plt.plot(a,b)
plt.title("Income")

plt.suptitle("My Shop")
plt.show()

# %% [markdown]
# ## Histogram

# %% [markdown]
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.

# %% [markdown]
# ### Create Histogram

# %% [markdown]
# * In Matplotlib, we use the hist() function to create histograms.
#
# * The hist() function will use an array of numbers to create a histogram, the array is sent into the function as an argument.

# %% [markdown]
# Example: For simplicity we use NumPy to randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.normal(170,10,250)
print(x)
plt.hist(x)
plt.show()
# Out:
# [181.10970284 170.89443664 156.28366261 164.01646211 169.98193677
#  170.00924578 167.68605089 161.99241903 178.80216229 175.85071159
#  147.49567162 167.29434157 170.6726995  171.08095376 180.72298096
#  169.0707026  170.1569595  166.99086366 174.66303642 158.81159061
#  160.52664375 170.13212248 181.20601294 161.81069991 184.01803875
#  160.43010172 182.71405826 171.66815645 167.45320575 166.37849307
#  175.63431584 172.52924514 167.15843148 180.13840651 177.80016038
#  161.6568443  176.78854245 167.673138   175.22014672 184.73304759
#  160.44559299 172.78586286 162.89664713 173.17193632 173.88775711
#  163.98717759 163.60685782 164.29528312 163.47514815 177.17902121
#  173.29170003 168.38334552 191.60579115 172.621321   156.13653729
#  192.00239272 176.13495675 162.15742404 160.09708493 155.43708422
#  168.73225556 183.48689588 168.9129153  155.23916263 185.22682248
#  181.27930803 175.89571485 183.65255544 159.2369071  190.70995698
# ...

# %% [markdown]
# ## Pie Charts

# %% [markdown]
# ### Creating Pie Charts
#
# With Pyplot, you can use the pie() function to draw pie charts.

# %% [markdown]
# By default the plotting of the first wedge starts from the x-axis and moves counterclockwise.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,3,5,6])
y=np.array([5,9,10,8])
plt.subplot(1,2,1)
plt.plot(x,y,marker='o')
plt.title("Normal")
plt.subplot(1,2,2)
plt.pie(x)
plt.title("Pie Chart")
plt.show()

# %% [markdown]
# * The size of each wedge is determined by comparing the value with all the other values, by using this formula:
#
# * The value divided by the sum of all values: x/sum(x)

# %% [markdown]
# ## Labels

# %% [markdown]
# * Add labels to the pie chart with the label parameter.
#
# * The label parameter must be an array with one label for each wedge

# %%
import matplotlib.pyplot as plt
import numpy as np
fruits=np.array([23,45,65,89])
fruits_label=['Apples','Mangos','Banana','Orange']
plt.pie(fruits,labels=fruits_label)
plt.show()

# %% [markdown]
# ### Start Angle
#
#
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
#
# The startangle parameter is defined with an angle in degrees, default angle is 0

# %%
import matplotlib.pyplot as plt
import numpy as np
fruits=np.array([23,45,65,89])
fruits_label=['Apples','Mangos','Banana','Orange']
plt.pie(fruits,labels=fruits_label,startangle=45)
plt.show()

# %% [markdown]
# ### Explode
#
#
# * Maybe you want one of the wedges to stand out? The explode parameter allows you to do that.
#
# * The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# * Each value represents how far from the center each wedge is displayed

# %%
import matplotlib.pyplot as plt
import numpy as np
fruits=np.array([23,45,65,89])
fruits_label=['Apples','Mangos','Banana','Orange']
myexplode=[0.2,0.1,0.1,0]
plt.pie(fruits,labels=fruits_label,explode=myexplode)
plt.show()

# %% [markdown]
# ### Shadow
#
# Add a shadow to the pie chart by setting the shadows parameter to True

# %%
import matplotlib.pyplot as plt
import numpy as np
fruits=np.array([23,45,65,89])
fruits_label=['Apples','Mangos','Banana','Orange']
myexplode=[0.2,0.1,0.1,0]
plt.pie(fruits,labels=fruits_label,explode=myexplode,shadow=True)
plt.show()

# %% [markdown]
# ### Colors
#
# * You can set the color of each wedge with the colors parameter.
#
# * The colors parameter, if specified, must be an array with one value for each wedge.

# %%
import matplotlib.pyplot as plt
import numpy as np
fruits=np.array([23,45,65,89])
fruits_label=['Apples','Mangos','Banana','Orange']
fruits_label_colors=['red','yellow','green','orange']
myexplode=[0.2,0.1,0.1,0]
plt.pie(fruits,labels=fruits_label,explode=myexplode,shadow=True,colors=fruits_label_colors)
plt.show()

# %% [markdown]
# ### Legend
#
# To add a list of explanation for each wedge, use the legend() function

# %%
import matplotlib.pyplot as plt
import numpy as np
fruits=np.array([23,45,65,89])
fruits_label=['Apples','Mangos','Banana','Orange']
fruits_label_colors=['red','yellow','green','orange']
myexplode=[0.2,0.1,0.1,0]
plt.pie(fruits,labels=fruits_label,explode=myexplode,shadow=True,colors=fruits_label_colors)
plt.legend()
plt.show()

# %% [markdown]
# ### Legend wih Header
#
# * To add a header to the legend, add the title parameter to the legend function.

# %% [markdown]
# * To locate Legend, supported values are 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center'.

# %%
import matplotlib.pyplot as plt
import numpy as np
fruits=np.array([23,45,65,89])
fruits_label=['Apples','Mangos','Banana','Orange']
fruits_label_colors=['red','yellow','green','orange']
myexplode=[0.2,0.1,0.1,0]
plt.pie(fruits,labels=fruits_label,explode=myexplode,shadow=True,colors=fruits_label_colors)
plt.legend(title="Fruits:",loc='lower left')
plt.show()

# %% [markdown]
# ## Bars

# %% [markdown]
# ### Creating Bars
#
# * With Pyplot, you can use the bar() function to draw bar graphs.
#
# * The bar() function takes arguments that describes the layout of the bars.
#
# * The categories and their values represented by the first and second argument as arrays.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([12,19,5,6])
y=['A','B','C','D']
plt.bar(y,x)
plt.show()

# %% [markdown]
# ### Horizonal Bars
#
# If you want the bars to be displayed horizontally instead of vertically, use the barh() function.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([12,19,5,6])
y=['A','B','C','D']
plt.barh(y,x)
plt.show()

# %% [markdown]
# ### Bar Color
#
# The bar() and barh() take the keyword argument color to set the color of the bars.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([12,19,5,6])
y=['A','B','C','D']

plt.subplot(1,2,1)
plt.barh(y,x,color='r')
plt.title("Horizontal Bars:",loc='left')

plt.subplot(1,2,2)
plt.bar(y,x,color='g')
plt.title("Vertical Bars:",loc='left')

plt.show()

# %% [markdown]
# ### Bar Width
#
# The bar() takes the keyword argument width to set the width of the bars.

# %% [markdown]
# ### Bar Height
#
# The barh() takes the keyword argument height to set the height of the bars.
#
# Note: For horizontal bars, use height instead of width.
#
# The default width,heigth value is 0.8

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([12,19,5,6])
y=['A','B','C','D']

plt.subplot(1,2,1)
plt.barh(y,x,color='r',height=0.2)
plt.title("Horizontal Bars:",loc='left')

plt.subplot(1,2,2)
plt.bar(y,x,color='g',width=0.2)
plt.title("Vertical Bars:",loc='left')

plt.show()

# %% [markdown]
# ### Scatter

# %% [markdown]
# #### Creating Scatter Plots
#
# * With Pyplot, you can use the scatter() function to draw a scatter plot.
#
# * The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,3,5,7])
y=np.array([2,4,6,8])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### Compare Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,3,5,7])
y=np.array([2,4,6,8])
plt.scatter(x,y)

x=np.array([4,6,8,10])
y=np.array([3,5,7,9])
plt.scatter(x,y)

plt.show()

# %% [markdown]
# ### Colors
#
# You can set your own color for each scatter plot with the color or the c argument.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,3,5,7])
y=np.array([2,4,6,8])
plt.scatter(x,y,c='hotpink')

x=np.array([4,6,8,10])
y=np.array([3,5,7,9])
plt.scatter(x,y,c='#88c999')

plt.show()

# %% [markdown]
# ### Color Each Dot
#
# You can even set a specific color for each dot by using an array of colors as value for the c argument.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,3,5,7])
y=np.array([2,4,6,8])
dots_color=['red','green','blue','yellow']
plt.scatter(x,y,c=dots_color)

plt.show()

# %% [markdown]
# ### ColorMap
#
# * The Matplotlib module has a number of available colormaps.
#
# * A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.
#
# * This colormap is called 'viridis' and as you can see it ranges from 0, which is a purple color, up to 100, which is a yellow color.

# %% [markdown]
# ### How to Use the ColorMap
#
# * You can specify the colormap with the keyword argument cmap with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.

# %% [markdown]
# * You can include the colormap in the drawing by including the plt.colorbar() statement.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,3,5,7])
y=np.array([2,4,6,8])
dot_colors=np.array([0,10,25,34])
plt.scatter(x,y,cmap='viridis',c=dot_colors)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Size
#
# * You can change the size of the dots with the s argument.
#
# * Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,3,5,7])
y=np.array([2,4,6,8])
dot_sizes=np.array([20,85,45,94])
plt.scatter(x,y,s=dot_sizes)
plt.show()

# %% [markdown]
# ### Alpha
#
# * You can adjust the transparency of the dots with the alpha argument.
#
# * Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,3,5,7])
y=np.array([2,4,6,8])
dot_sizes=np.array([20,85,45,94])
plt.scatter(x,y,s=dot_sizes,alpha=0.5)
plt.show()

# %% [markdown]
# * Combine Color Size and Alpha
#
# * You can combine a colormap with different sizes of the dots. This is best visualized if the dots are transparent.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# # END
